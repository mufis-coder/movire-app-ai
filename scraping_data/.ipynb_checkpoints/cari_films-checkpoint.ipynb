# %%
# # Import scrapy
# import scrapy

# # Import the CrawlerProcess: for running the spider
# from scrapy.crawler import CrawlerProcess

# # Create the Spider class
# class DC_Description_Spider(scrapy.Spider):
#     name = "dc_chapter_spider"
#   # start_requests method
#     def start_requests(self):
#         url = 'https://learn.datacamp.com/courses'
#         yield scrapy.Request(url = url,
#                          callback = self.parse_front)
#   # First parsing metho
#     def parse_front(self, response):
#         pass
# #         course_blocks = response.css('div.course-block')
# #         course_links = course_blocks.xpath('./a/@href')
# #         links_to_follow = course_links.extract()
# #         for url in links_to_follow:
# #             yield response.follow(url = url,
# #                                 callback = self.parse_pages)
#   # Second parsing method
#     def parse_pages(self, response):
#         pass
# #         # Create a SelectorList of the course titles text
# #         crs_title = response.xpath('//h1[contains(@class,"title")]/text()')
# #         # Extract the text and strip it clean
# #         crs_title_ext = crs_title.extract_first().strip()
# #         # Create a SelectorList of course descriptions text
# #         crs_descr = response.css( 'p.course__description::text' )
# #         # Extract the text and strip it clean
# #         crs_descr_ext = crs_descr.extract_first().strip()
# #         # Fill in the dictionary
# #         dc_dict[crs_title_ext] = crs_descr_ext

# # Initialize the dictionary **outside** of the Spider class
# dc_dict = dict()

# # Run the Spider
# process = CrawlerProcess()
# process.crawl(DC_Description_Spider)
# process.start()

# # Print a preview of courses
# # previewCourses(dc_dict)

# %%
# dc_dict

# %%
# # parse method
# def parse(self, response):
#   # Extracted course titles
#   crs_titles = response.xpath('//h4[contains(@class,"block__title")]/text()').extract()
#   # Extracted course descriptions
#   crs_descrs = response.xpath('//p[contains(@class,"block__description")]/text()').extract()
#   # Fill in the dictionary
#   for crs_title, crs_descr in zip(crs_titles, crs_descrs):
#     dc_dict[crs_title] = crs_descr

# %%
import scrapy
from scrapy.crawler import CrawlerProcess
from scrapy.shell import inspect_response
class DC_Description_Spider(scrapy.Spider):
    name = "dc_chapter_spider"
    
    def start_requests(self):
        url_short = 'https://carifilms.com/films?order=DESC&is_meta_key=0&orderby=title'
        yield scrapy.Request(url = url_short, callback = self.parse_awalpage)
    
#     def parse_awalpage(self, response):
#         next_page = response.xpath('//a[@class="next page-numbers"]/@href')
#         next_page_link = next_page.extract()
#         if next_page_link:
#             next_href = next_page_link[0]
#             print(next_href)
#             request = scrapy.Request(url=next_href, callback = self.parse_awalpage)
#             yield request
        
    def parse_awalpage(self, response):
#         print(response.text)
        block_film_page = response.css('div.container-fluid ')
        film_link = block_film_page.xpath('.//a[@class="section__film-info__entitle"]/@href')
        links_to_follow = film_link.extract()
        for url in links_to_follow:
#             print(url)
#             yield response.follow(url, callback = self.parse_pages)
#             yield scrapy.Request(url = url, callback = self.parse_pages)
            
#     def parse_pages(self, response):
#         print(response.text)
#         inspect_response(response, self)
#         film_title = response.xpath('//h1[contains(@class,"section__film-info__entitle section__title")]/text()')
#         film_title_ext = film_title.extract_first().strip()
#         print(film_title_ext)
#         crs_descr = response.css( 'p.course__description::text' )
#         # Extract the text and strip it clean
#         crs_descr_ext = crs_descr.extract_first().strip()
#         # Fill in the dictionary
#         dc_dict[crs_title_ext] = crs_descr_ext

# %%
process = CrawlerProcess()
process.crawl(DC_Description_Spider)
process.start()
# process.start(stop_after_crawl=False)
# Out:
# 2020-12-04 11:03:09 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2020-12-04 11:03:09 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 20.3.0, Python 3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Windows-10-10.0.18362-SP0
# 2020-12-04 11:03:09 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-12-04 11:03:09 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2020-12-04 11:03:09 [scrapy.extensions.telnet] INFO: Telnet Password: efad8095f2202034
# 2020-12-04 11:03:09 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2020-12-04 11:03:09 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-12-04 11:03:09 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-12-04 11:03:09 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-12-04 11:03:09 [scrapy.core.engine] INFO: Spider opened
# 2020-12-04 11:03:09 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-12-04 11:03:09 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6030
# 2020-12-04 11:03:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://carifilms.com/films?order=DESC&is_meta_key=0&orderby=title> (referer: None)
# 2020-12-04 11:03:14 [scrapy.core.scraper] ERROR: Spider error processing <GET https://carifilms.com/films?order=DESC&is_meta_key=0&orderby=title> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\ACER\anaconda3\lib\site-packages\twisted\internet\defer.py", line 1418, in _inlineCallbacks
#     result = g.send(result)
# StopIteration: <200 https://carifilms.com/films?order=DESC&is_meta_key=0&orderby=title>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ACER\anaconda3\lib\site-packages\scrapy\utils\defer.py", line 55, in mustbe_deferred
#     result = f(*args, **kw)
#   File "C:\Users\ACER\anaconda3\lib\site-packages\scrapy\core\spidermw.py", line 58, in process_spider_input
#     return scrape_func(response, request, spider)
#   File "C:\Users\ACER\anaconda3\lib\site-packages\scrapy\core\scraper.py", line 149, in call_spider
#     warn_on_generator_with_return_value(spider, callback)
#   File "C:\Users\ACER\anaconda3\lib\site-packages\scrapy\utils\misc.py", line 245, in warn_on_generator_with_return_value
#     if is_generator_with_return_value(callable):
#   File "C:\Users\ACER\anaconda3\lib\site-packages\scrapy\utils\misc.py", line 230, in is_generator_with_return_value
#     tree = ast.parse(dedent(inspect.getsource(callable)))
#   File "C:\Users\ACER\anaconda3\lib\ast.py", line 35, in parse
#     return compile(source, filename, mode, PyCF_ONLY_AST)
#   File "<unknown>", line 1
#     def parse_awalpage(self, response):
#     ^
# IndentationError: unexpected indent
# 2020-12-04 11:03:14 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-12-04 11:03:14 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 257,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 12185,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 4.869717,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 12, 4, 4, 3, 14, 509392),
#  'log_count/DEBUG': 1,
#  'log_count/ERROR': 1,
#  'log_count/INFO': 10,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'spider_exceptions/IndentationError': 1,
#  'start_time': datetime.datetime(2020, 12, 4, 4, 3, 9, 639675)}
# 2020-12-04 11:03:14 [scrapy.core.engine] INFO: Spider closed (finished)
